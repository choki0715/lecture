# %% [markdown]
# <a href="https://colab.research.google.com/github/choki0715/lecture/blob/master/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 새 환경 생성
conda create -n simple_quant python=3.10 -y
conda activate simple_quant

# 필수 패키지만 설치 (3개만!)
pip install torch transformers bitsandbytes
pip install accelerate
pip install psutil
