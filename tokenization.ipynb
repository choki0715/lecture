# %% [markdown]
# <a href="https://colab.research.google.com/github/choki0715/lecture/blob/master/tokenization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## OpenAI 토크나이저 사용

# %%
pip install tiktoken

# %% [markdown]
# #한국어, 영어, 일어, 중국어의 토큰화 예시

# %%
import tiktoken

text_ko = "토큰에 대해서 배우고 있는 중입니다! 한국이 일본을 5:0으로 이겼습니다"
text_en = "I am learning about tokens! Korea beat Japan 5:0"
text_jp = "トークンについて学んでいます！ 韓国が日本を5：0に勝った"
text_cn = "我正在學習代幣！ 韓國隊5:0擊敗日本隊"

# %% [markdown]
# # 토큰화와 인코딩(임베딩) 옵션 결정
# ![tiktoken_image.jpg](data:image/jpeg;base64,...)

# %%
encoding = tiktoken.get_encoding("cl100k_base")
encoding = tiktoken.encoding_for_model("gpt-4")

# %% [markdown]
# # 토큰화와 인코딩(임베딩)

# %%
# text_ko = "토큰에 대해서 배우고 있는 중입니다! 한국이 일본을 5:0으로 이겼습니다"
my_token_ko1=encoding.encode(text_ko)

# text_en = "I am learning about tokens! Korea beat Japan 5:0"
my_token_en1=encoding.encode(text_en)

# text_jp = "トークンについて学んでいます！ 韓国が日本を5：0に勝った"
my_token_jp1=encoding.encode(text_jp)

# text_cn = "我正在學習代幣！ 韓國隊5:0擊敗日本隊"
my_token_cn1=encoding.encode(text_cn)

print(my_token_ko1, len(my_token_ko1))
print(my_token_en1, len(my_token_en1))
print(my_token_jp1, len(my_token_jp1))
print(my_token_cn1, len(my_token_cn1))

# 토큰 타입 알아보기
type(my_token_ko1), type(my_token_en1), type(my_token_jp1), type(my_token_cn1)
# Out:
# [169, 228, 58260, 223, 108, 19954, 62060, 97237, 74769, 41381, 35495, 65621, 72043, 80052, 0, 62398, 89059, 255, 13094, 84656, 29099, 116, 18359, 220, 20, 25, 15, 43139, 23955, 28740, 120, 39331] 32
# [40, 1097, 6975, 922, 11460, 0, 12126, 9567, 6457, 220, 20, 25, 15] 13
# [20251, 11972, 29220, 16073, 20230, 59739, 16995, 38144, 48864, 25827, 16556, 61689, 6447, 18630, 253, 241, 29504, 29295, 9080, 22656, 30512, 20, 5232, 15, 20230, 53508, 251, 42891, 28713] 29
# [37046, 97655, 10890, 116, 163, 123, 240, 31640, 7190, 96, 6447, 18630, 253, 241, 12554, 233, 37795, 232, 20, 25, 15, 162, 241, 232, 8067, 245, 9080, 22656, 37795, 232] 30
# (list, list, list, list)

# %% [markdown]
# #인코딩된 토큰을 원래 문자로 디코딩

# %%
dec_ko = encoding.decode(my_token_ko1)
dec_en = encoding.decode(my_token_en1)
dec_jp = encoding.decode(my_token_jp1)
dec_cn = encoding.decode(my_token_cn1)

print(dec_ko)
print(dec_en)
print(dec_jp)
print(dec_cn)
# Out:
# 토큰에 대해서 배우고 있는 중입니다! 한국이 일본을 5:0으로 이겼습니다
# I am learning about tokens! Korea beat Japan 5:0
# トークンについて学んでいます！ 韓国が日本を5：0に勝った
# 我正在學習代幣！ 韓國隊5:0擊敗日本隊

# %%
res = [0]
print (res)
for code in my_token_cn1:
  res[0]=code
  print(code, encoding.decode(res))
# Out:
# [0]
# 37046 我
# 97655 正在
# 10890 �
# 116 �
# 163 �
# 123 �
# 240 �
# 31640 代
# 7190 �
# 96 �
# 6447 ！
# 18630  �
# 253 �
# 241 �
# 12554 �
# 233 �
# 37795 �
# 232 �
# 20 5
# 25 :
# 15 0
# 162 �
# 241 �
# 232 �
# 8067 �
# 245 �
# 9080 日
# 22656 本
# 37795 �
# 232 �

# %% [markdown]
# # 파이썬 표준 토큰화 라이브러리 사용하기: nltk

# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
my_token2 = word_tokenize(text_jp)
print(my_token2, len(my_token2))
# Out:
# ['トークンについて学んでいます！', '韓国が日本を5：0に勝った'] 2

# %%
from nltk.tokenize import TreebankWordTokenizer

my_token3 = TreebankWordTokenizer().tokenize(text_cn)
print(my_token3, len(my_token3))
# Out:
# ['我正在學習代幣！', '韓國隊5:0擊敗日本隊'] 2
