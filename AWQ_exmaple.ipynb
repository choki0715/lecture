# %% [markdown]
# <a href="https://colab.research.google.com/github/choki0715/lecture/blob/master/AWQ_exmaple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U transformers autoawq

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer

model_id = "TheBloke/zephyr-7B-alpha-AWQ"
model = AutoModelForCausalLM.from_pretrained(model_id, device_map="cuda:0")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
# 모델 파라미터 확인
for name, param in model.named_parameters():
    print(f"Parameter: {name}, dtype: {param.dtype}, shape: {param.shape}")
# Out:
# Parameter: model.embed_tokens.weight, dtype: torch.float16, shape: torch.Size([32000, 4096])
# Parameter: model.layers.0.input_layernorm.weight, dtype: torch.float16, shape: torch.Size([4096])
# Parameter: model.layers.0.post_attention_layernorm.weight, dtype: torch.float16, shape: torch.Size([4096])
# Parameter: model.layers.1.input_layernorm.weight, dtype: torch.float16, shape: torch.Size([4096])
# Parameter: model.layers.1.post_attention_layernorm.weight, dtype: torch.float16, shape: torch.Size([4096])
# Parameter: model.layers.2.input_layernorm.weight, dtype: torch.float16, shape: torch.Size([4096])
# Parameter: model.layers.2.post_attention_layernorm.weight, dtype: torch.float16, shape: torch.Size([4096])
# Parameter: model.layers.3.input_layernorm.weight, dtype: torch.float16, shape: torch.Size([4096])
# Parameter: model.layers.3.post_attention_layernorm.weight, dtype: torch.float16, shape: torch.Size([4096])
# ...

# %%
import torch
from transformers import AwqConfig, AutoModelForCausalLM

model_id = "TheBloke/zephyr-7B-alpha-AWQ"

quantization_config = AwqConfig(
    bits=4,
    # fuse_max_seq_len=512,
    # do_fuse=True,
)

model = AutoModelForCausalLM.from_pretrained(model_id, quantization_config=quantization_config, device_map="cuda:0")

# %%
# 모델 파라미터 확인
for name, param in model.named_parameters():
    print(f"Parameter: {name}, dtype: {param.dtype}, shape: {param.shape}")
# Out:
# Parameter: model.embed_tokens.weight, dtype: torch.float16, shape: torch.Size([32000, 4096])
# Parameter: model.layers.0.input_layernorm.weight, dtype: torch.float16, shape: torch.Size([4096])
# Parameter: model.layers.0.post_attention_layernorm.weight, dtype: torch.float16, shape: torch.Size([4096])
# Parameter: model.layers.1.input_layernorm.weight, dtype: torch.float16, shape: torch.Size([4096])
# Parameter: model.layers.1.post_attention_layernorm.weight, dtype: torch.float16, shape: torch.Size([4096])
# Parameter: model.layers.2.input_layernorm.weight, dtype: torch.float16, shape: torch.Size([4096])
# Parameter: model.layers.2.post_attention_layernorm.weight, dtype: torch.float16, shape: torch.Size([4096])
# Parameter: model.layers.3.input_layernorm.weight, dtype: torch.float16, shape: torch.Size([4096])
# Parameter: model.layers.3.post_attention_layernorm.weight, dtype: torch.float16, shape: torch.Size([4096])
# ...

# %%
import torch
from transformers import AwqConfig, AutoModelForCausalLM

model_id = "TheBloke/Mistral-7B-OpenOrca-AWQ"

quantization_config = AwqConfig(
    bits=4,
    fuse_max_seq_len=512,
    do_fuse=True,
)

model = AutoModelForCausalLM.from_pretrained(model_id, quantization_config=quantization_config).to("cuda")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...

# %%
# 모델 파라미터 확인
for name, param in model.named_parameters():
    print(f"Parameter: {name}, dtype: {param.dtype}, shape: {param.shape}")
# Out:
# Parameter: model.embed_tokens.weight, dtype: torch.float16, shape: torch.Size([32002, 4096])
# Parameter: model.layers.0.self_attn.rope.freqs_cis, dtype: torch.complex64, shape: torch.Size([1024, 64])
# Parameter: model.layers.0.input_layernorm.weight, dtype: torch.float16, shape: torch.Size([4096])
# Parameter: model.layers.0.post_attention_layernorm.weight, dtype: torch.float16, shape: torch.Size([4096])
# Parameter: model.layers.1.self_attn.rope.freqs_cis, dtype: torch.complex64, shape: torch.Size([1024, 64])
# Parameter: model.layers.1.input_layernorm.weight, dtype: torch.float16, shape: torch.Size([4096])
# Parameter: model.layers.1.post_attention_layernorm.weight, dtype: torch.float16, shape: torch.Size([4096])
# Parameter: model.layers.2.self_attn.rope.freqs_cis, dtype: torch.complex64, shape: torch.Size([1024, 64])
# Parameter: model.layers.2.input_layernorm.weight, dtype: torch.float16, shape: torch.Size([4096])
# ...
